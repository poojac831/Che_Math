# %% [markdown]
# # Homework 7 Flow, Bifurcation and Linearization

# %% [markdown]
# # Problem 1 Flow and Bifurcation
#
# 1. You are studying energy potential diagrams and come across the following equation:
# $\frac{dx}{dt} = rx+x^3-x^5$. Let **r = -2** and use the code cell below to plot the flow figure. Be sure to label axes. Some quick hints:
# - You will likely have to zoom into the figure to see the important points. Consider using ylim and xlim.
# - It may help to draw an abline at y = 0. Look up the command "axhline".

# %%
#importing necessary libraries
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint

#define equation
def dxdt(x):
    #r value we're doing flow on a line with
    r = -2
    
    dxdt = r*x+x**3-x**5
    return dxdt

#define x valus
x_values = np.linspace(-3,3,100)

#solve for dxdt values
dxdtval = []
for m in x_values:
    dxdtval.append(dxdt(m))

#plot!
plt.xlabel("x")
plt.ylabel("dx/dt")
plt.title("Flow on a Line at r=-2")
plt.ylim(-2,2)
plt.grid()
plt.axhline(0,color = 'r')
plt.plot(x_values,dxdtval)
plt.plot([0],[0], color='green', marker = 'o', linestyle = 'none',markersize=12);

# %% [markdown]
# In the cell below answer : How many steadystates are there and what are their *approximate* values (i.e. zoom into the figure and read them from the diagram)? Describe the stability of each steady state.

# %% [markdown]
# <font color=red>There is only one steady state, marked with a green dot on the diagram. It's value is at approximately x = 0. It is a stable steady state as well.</font>

# %% [markdown]
# To ensure we understand what the flow diagram means in terms of the dynamic changes in the value of x over time, please use an ode solver to simulate the ODE with $x_0 = 0.8$. Plot the value of x versus time in the space below. For the simulation time and time step size, choose appropriate numbers such that the plot is smooth and the figure clearly shows the approach to steadystate.

# %%
#setting initial condition and time
x0=0.8
timesteps = np.arange(0,10,0.1)

#define equation
def dxdt(x,t):
    #r value we're doing flow on a line with
    r = -2
    
    dxdt = r*x+x**3-x**5
    return dxdt

#solving the ODE
ODE_output = odeint(dxdt,x0,timesteps)

#plot!
plt.xlabel("Time")
plt.ylabel("x(t)")
plt.title("ODE simulated at x$_{0}$=0.8")
plt.grid()
plt.plot(timesteps,ODE_output)

# %% [markdown]
# Now replot the flow diagram for **r = -.2**.

# %%
#importing necessary libraries
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint

#define equation
def dxdt(x):
    #r value we're doing flow on a line with
    r = -.2
    
    dxdt = r*x+x**3-x**5
    return dxdt

#define x values
x_values = np.linspace(-3,3,100)

#solving dxdt
dxdtval = []
for m in x_values:
    dxdtval.append(dxdt(m))
    
#plot!
plt.xlabel("x")
plt.ylabel("dx/dt")
plt.title("Flow on a Line at r=-.2")
plt.ylim(-1,1)
plt.xlim(-1.5,1.5)
plt.grid()
plt.axhline(0,color = 'r')
plt.plot(x_values,dxdtval)
plt.plot([-0.85,0,0.85],[0,0,0], color='green', marker = 'o', linestyle = 'none',markersize=12);
plt.plot([-0.5,0.5],[0,0], color='red', marker = 'o', linestyle = 'none',markersize=12);

# %% [markdown]
# In the cell below answer : How many steadystates are there and what are their approximate values (i.e. zoom into the figure and read them from the diagram)? Describe the stability of each steady state.

# %% [markdown]
# <font color=red>There are five steady states. From left to right on the diagram, their approximate values are $x_{1}$=-0.85, $x_{2}$=-0.5, $x_{3}$=0, $x_{4}$=0.5 and $x_{5}$=0.85. The stable steady states are marked with green dots on the plot and are found at -0.85, 0 and 0.85. The unstable steady states are marked with red dots and are found at -0.5 and 0.5.</font>

# %% [markdown]
# To ensure we understand what the flow diagram means in terms of the dynamic changes in the value of x over time, please use an ode solver to simulate the ODE with $x_0 = 0.8$. Plot the value of x versus time in the space below.

# %%
#setting initial condition and time
x0=0.8
timesteps = np.arange(0,100,0.1)

#define equation
def dxdt(x,t):
    #r value we're doing flow on a line with
    r = -.2
    
    dxdt = r*x+x**3-x**5
    return dxdt

#solving ODE
ODE_output = odeint(dxdt,x0,timesteps)

#plot!
plt.xlabel("Time")
plt.ylabel("x(t)")
plt.title("ODE simulated at x$_{0}$=0.8")
plt.grid()
plt.plot(timesteps,ODE_output)

# %% [markdown]
# Last time! Replot the flow diagram for **r = 2**.

# %%
#importing necessary libraries
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint

#define equation
def dxdt(x):
    #r value we're doing flow on a line with
    r = 2
    
    dxdt = r*x+x**3-x**5
    return dxdt

#define x values
x_values = np.linspace(-3,3,100)

#solving dxdt
dxdtval = []
for m in x_values:
    dxdtval.append(dxdt(m))
    
#plot!
plt.xlabel("x")
plt.ylabel("dx/dt")
plt.title("Flow on a Line at r=-.2")
plt.ylim(-25,25)
plt.xlim(-2,2)
plt.grid()
plt.axhline(0,color = 'r')
plt.plot(x_values,dxdtval)
plt.plot([-1.4,1.4],[0,0], color='green', marker = 'o', linestyle = 'none',markersize=12);
plt.plot([0],[0], color='red', marker = 'o', linestyle = 'none',markersize=12);

# %% [markdown]
# In the cell below answer : How many steadystates are there and what are their approximate values (i.e. zoom into the figure and read them from the diagram)? Describe the stability of each steady state.

# %% [markdown]
# <font color = red>There are three steady states. From left to right on the diagram, their approximate values are $x_{1}$ = -1.4, $x_{2}$ =  0, and $x_{3}$ = 1.4. The stable steady states are marked by green dots on the plot and are found at -1.4 and 1.4. The unstable steady state is marked by a red dot and is found at 0.</font>

# %% [markdown]
# To ensure we understand what the flow diagram means in terms of the dynamic changes in the value of x over time, please use an ode solver to simulate the ODE with  $x_0 = 0.8$. Plot the value of x versus time in the space below.

# %%
#setting initial condition and time
x0=0.8
timesteps = np.arange(0,20,0.1)

#define equation
def dxdt(x,t):
    #r value we're doing flow on a line with
    r = 2
    
    dxdt = r*x+x**3-x**5
    return dxdt

#solving ODE
ODE_output = odeint(dxdt,x0,timesteps)

#plot!
plt.xlabel("Time")
plt.ylabel("x(t)")
plt.title("ODE simulated at x$_{0}$=0.8")
plt.grid()
plt.plot(timesteps,ODE_output)

# %% [markdown]
# Putting everything together, the goal here is to emphasize that flow on a line makes it easy to understand first order ODE's steadystate and the system behavior near steadystate. But we also see here how quickly the number of steadystates and their stability changes with our choice of parameter values.
#
# Below, comment on how uncertainty in the value of r may impact your system.

# %% [markdown]
# <font color=red>Not knowing r changes how many steady states the system has. It also changes the stability of some of the constant steady states the system has like x = 0.</font>

# %% [markdown]
# # Problem 2 Linearization
#
# You're given the nonlinear, first-order, time-invariant ODE $\frac{dy}{dt} = sin(y)$.
#
# 1. In the space below, plot the flow diagram for the ODE.

# %%
# Import the required modules
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

#defining equation
def dydt(y):
    dydt = math.sin(y)
    return dydt


y_values = np.linspace(0,15,100)

dydt_values = []
for m in y_values:
    dydt_values.append(dydt(m))
    
# Plot derivative vs y
plt.xlabel('y')
plt.ylabel('dy/dt')
plt.title('Flow on a line for $dy/dt = sin(y)$')
plt.grid()
plt.axhline(0,color='r')
plt.plot(y_values,dydt_values);
plt.plot([math.pi,3*math.pi],[0,0], color='green', marker = 'o', linestyle = 'none',markersize=12);
plt.plot([0,2*math.pi,4*math.pi],[0,0,0], color='red', marker = 'o', linestyle = 'none',markersize=12);

# %% [markdown]
# 2. In the space below, type out the equation for the linearized form of our ODE when it is linearized about the lowest, positive-valued, stable steadystate.

# %% [markdown]
# <font color=red>$\frac{dy'}{dt}=\pi-y$</font>

# %% [markdown]
# 3. We want to compare the responses of our linearized model to our original nonlinear model. On a single figure, plot the time response of both models when starting at an initial conditions of $y_0 = 3$. Clearly indicate which lines represent which ODEs.

# %%
#setting initial condition and time
y0=3
timesteps = np.arange(0,20,0.1)

#define equation
def dydt(y,t):
    dydt = math.sin(y)
    return dydt

def linear(y,t):
    lin = math.pi-y
    return lin

#solving ODE
ODEsin = odeint(dydt,y0,timesteps)
ODElinear = odeint(linear,y0,timesteps)

#plot!
plt.xlabel("Time")
plt.ylabel("y(t), y'(t)")
plt.title("ODEs simulated at y$_{0}$=3")
plt.grid()
plt.plot(timesteps,ODEsin,'r*',label='Nonlinear Model')
plt.plot(timesteps,ODElinear, label="Linear Model")
plt.legend()

# %% [markdown]
# 3. Let's test one more initial condition. On a single figure, plot the time response of both models when starting at an initial conditions of $y_0 = 1$. Clearly indicate which lines represent which ODEs.

# %%
#setting initial condition and time
y0=1
timesteps = np.arange(0,20,0.1)

#define equation
def dydt(y,t):
    dydt = math.sin(y)
    return dydt

def linear(y,t):
    lin = math.pi-y
    return lin

#solving ODE
ODEsin = odeint(dydt,y0,timesteps)
ODElinear = odeint(linear,y0,timesteps)

#plot!
plt.xlabel("Time")
plt.ylabel("y(t), y'(t)")
plt.title("ODEs simulated at y$_{0}$=1")
plt.grid()
plt.plot(timesteps,ODEsin,'r*',label='Nonlinear Model')
plt.plot(timesteps,ODElinear, label="Linear Model")
plt.legend()

# %% [markdown]
# 4. Discuss the results from parts 3 and 4. Are the time trajectories of the linearized and nonlinear models similar? When should they be and when should they not be similar?
